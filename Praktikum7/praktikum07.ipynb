# %% [markdown]
# SVM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/praktikum_ml/praktikum07/data/apples_and_oranges.csv"

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv(path)
df
# Out:
#     Weight  Size   Class
# 0       69  4.39  orange
# 1       69  4.21  orange
# 2       65  4.09  orange
# 3       72  5.85   apple
# 4       67  4.70  orange
# 5       73  5.68   apple
# 6       70  5.56   apple
# 7       75  5.11   apple
# 8       74  5.36   apple
# 9       65  4.27  orange
# 10      73  5.79   apple
# 11      70  5.47   apple
# 12      74  5.53   apple
# 13      68  4.47  orange
# 14      74  5.22   apple
# 15      65  4.48  orange
# 16      69  4.66  orange
# 17      75  5.25   apple
# 18      67  4.18  orange
# 19      74  5.50   apple
# 20      66  4.13  orange
# 21      70  4.83  orange
# 22      69  4.61  orange
# 23      68  4.08  orange
# 24      67  4.25  orange
# 25      71  5.35   apple
# 26      67  4.01  orange
# 27      70  4.22  orange
# 28      74  5.25   apple
# 29      71  5.26   apple
# 30      73  5.78   apple
# 31      66  4.68  orange
# 32      72  5.72   apple
# 33      73  5.17   apple
# 34      68  4.83  orange
# 35      69  4.11  orange
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  40 non-null     int64
#  1   Size    40 non-null     float64
#  2   Class   40 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#           Weight       Size
# count  40.000000  40.000000
# mean   70.200000   4.922750
# std     3.039906   0.590063
# min    65.000000   4.010000
# 25%    68.000000   4.360000
# 50%    70.000000   4.930000
# 75%    73.000000   5.472500
# max    75.000000   5.850000

# %%
df["Class"].unique()
# Out:
# array(['orange', 'apple'], dtype=object)

# %%
df["Class"].value_counts()
# Out:
# Class
# orange    20
# apple     20
# Name: count, dtype: int64

# %% [markdown]
# Feature Selection

# %%
x = df[['Size', 'Weight']]

y = df['Class']

# %%
x.head()
# Out:
#    Size  Weight
# 0  4.39      69
# 1  4.21      69
# 2  4.09      65
# 3  5.85      72
# 4  4.70      67

# %%
y.head()
# Out:
# 0    orange
# 1    orange
# 2    orange
# 3     apple
# 4    orange
# Name: Class, dtype: object

# %% [markdown]
# Split dan bangun Model SVM

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = SVC(kernel='linear')
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Evaluasi Akurasi dan Report

# %%
y_pred = model.predict(x_test)
print(f"Akurasi: {accuracy_score(y_test, y_pred) * 100:.2f}%")
print("\nLaporan Klassifikasi:\n", classification_report(y_test, y_pred))
# Out:
# Akurasi: 100.00%
#
# Laporan Klassifikasi:
#                precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00         3
#       orange       1.00      1.00      1.00         5
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %% [markdown]
# Confusion Matrix

# %%
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Confusion Matrix:
#  [[3 0]
#  [0 5]]

# %% [markdown]
# Visualisasi Model

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Size'], df['Weight'], c=df['Class'].astype('category').cat.codes)
plt.xlabel('size')
plt.ylabel('Weight')
plt.title('Visualisasi apele and oranges')
plt.show()

# %% [markdown]
# 3D

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from mpl_toolkits.mplot3d import Axes3D

# Encode label (ubah teks jadi angka)
le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])

# Plot 3D hasil klasifikasi
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Warna untuk tiap kelas
colors = ['r', 'y']
labels = le.classes_

# Plot tiap spesies dengan warna berbeda
for i, species in enumerate(labels):
    subset = df[df['Class'] == i]
    ax.scatter(
        subset['Weight'],
        subset['Size'],
        subset['Size'],
        color=colors[i],
        label=species,
        s=50
    )

ax.set_xlabel('Weight')
ax.set_ylabel('Size')
ax.set_title('3D Visualisasi apell and oranges')
ax.legend()
plt.show()

print("Data x_train")
display(x_train.head())

print("Data y_train")
display(y_train.head())
model.fit(x_train, y_train)
# Out:
# Data x_train
#     Size  Weight
# 39  5.03      73
# 6   5.56      70
# 25  5.35      71
# 9   4.27      65
# 13  4.47      68
# Data y_train
# 39     apple
# 6      apple
# 25     apple
# 9     orange
# 13    orange
# Name: Class, dtype: object
# SVC(kernel='linear')

# %%
import plotly.express as px

fig = px.scatter_3d(df, x='Weight', y='Size', z='Size',
                    color='Class', symbol='Class',
                    title='3D Visualization of Apples and Oranges')

fig.update_layout(scene = dict(
                    xaxis_title='Weight',
                    yaxis_title='Size',
                    zaxis_title='Size'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
