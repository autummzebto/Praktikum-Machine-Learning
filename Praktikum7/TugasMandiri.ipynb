# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/praktikum_ml/praktikum07/data/dataset_satelit.csv"

# %% [markdown]
# Pertama, kita mengimpor semua library yang diperlukan, seperti Pandas untuk mengelola data, Matplotlib/Seaborn untuk visualisasi, dan Scikit-learn (sklearn) untuk model Regresi Linear serta metrik evaluasi

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# Library  untuk membaca dan mengolah data (pandas, numpy), membagi dataset menjadi data latih dan data uji (train_test_split), membangun model regresi linier (LinearRegression), dan menghitung performa model (r2_score, mean_squared_error).

# %% [markdown]
# # **Load Data**

# %%
df = pd.read_csv(path)
df
# Out:
#       No   Longitude  Lattitude     N     P      K    Ca    Mg      Fe  \
# 0      1  103.036658  -0.604417  2.64  0.15  0.415  0.51  0.31  119.96
# 1      2  103.037201  -0.604689  2.75  0.17  0.568  0.76  0.58  102.63
# 2      3  103.036359  -0.603012  1.77  0.12  0.339  0.49   0.6  107.37
# 3      4  103.036950  -0.603219  2.30  0.15  0.460  0.74  0.67   96.02
# 4      5  103.036802  -0.601969  2.05  0.14  0.308  0.64  0.72   87.01
# ..   ...         ...        ...   ...   ...    ...   ...   ...     ...
# 589  590  103.605867   0.057633  2.49  0.16  0.347  0.78  0.86   63.38
# 590  591  103.606717   0.057100  2.74  0.15  0.466  0.73   0.5   51.04
# 591  592  103.606250   0.056767  2.63  0.15  0.422  0.82  0.59   82.57
# 592  593  103.606400   0.056517  2.75  0.17  0.502  0.69  0.53  102.07
# 593  594  103.606033   0.056317  2.71  0.15  0.419  0.78  0.46   90.60
#
#          Mn  ...      b1  Sigma_VV  Sigma_VH      plia       lia      iafe  \
# ...

# %% [markdown]
# Dataset dibaca dari Google Drive, berisi data pengukuran satelit yang mencakup nilai kimia tanah (N, P, K, Ca, dll.) dan reflektansi spektral (band b1–b12, Sigma_VV, Sigma_VH,).

# %% [markdown]
# Interpretasi Kolom

# %% [markdown]
# Bagian ini menampilkan struktur dataset:
#
# *   Total 594 baris dan 34 kolom.
# *   Terdapat satu kolom bertipe object, yaitu Mg, yang seharusnya numerik.
# * df.describe() menunjukkan nilai statistik dasar (mean, min, max) dari setiap fitur.
# * df.columns digunakan untuk memastikan nama-nama kolom sesuai dengan kebutuhan analisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         594 non-null    int64
#  1   Longitude  594 non-null    float64
#  2   Lattitude  594 non-null    float64
#  3   N          594 non-null    float64
#  4   P          594 non-null    float64
#  5   K          593 non-null    float64
#  6   Ca         594 non-null    float64
#  7   Mg         594 non-null    object
#  8   Fe         594 non-null    float64
#  9   Mn         594 non-null    float64
#  10  Cu         594 non-null    float64
#  11  Zn         594 non-null    float64
#  12  B          594 non-null    float64
#  13  b12        594 non-null    float64
#  14  b11        594 non-null    float64
#  15  b9         594 non-null    float64
#  16  b8a        594 non-null    float64
#  17  b8         594 non-null    float64
#  18  b7         594 non-null    float64
# ...

# %%
df.describe()
# Out:
#                No   Longitude   Lattitude           N           P           K  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  593.000000
# mean   297.500000  106.878644   -1.024933    2.259091    0.141380    0.582175
# std    171.617307    4.949840    0.965349    0.395499    0.019782    0.222567
# min      1.000000  102.760857   -2.333750    1.140000    0.090000    0.122000
# 25%    149.250000  102.927811   -2.233338    1.982500    0.130000    0.429000
# 50%    297.500000  103.581969   -0.602276    2.280000    0.140000    0.549000
# 75%    445.750000  113.403797   -0.257349    2.570000    0.150000    0.710000
# max    594.000000  113.434700    0.069251    3.230000    0.220000    1.489000
#
#                Ca          Fe           Mn          Cu  ...          b1  \
# count  594.000000  594.000000   594.000000  594.000000  ...  594.000000
# mean     0.595094   74.613771   308.034697    2.391195  ...    0.177291
# ...

# %%
df.columns
# Out:
# Index(['No', 'Longitude', 'Lattitude', 'N', 'P', 'K', 'Ca', 'Mg', 'Fe', 'Mn',
#        'Cu', 'Zn', 'B', 'b12', 'b11', 'b9', 'b8a', 'b8', 'b7', 'b6', 'b5',
#        'b4', 'b3', 'b2', 'b1', 'Sigma_VV', 'Sigma_VH', 'plia', 'lia', 'iafe',
#        'gamma0_vv', 'gamma0_vh', 'beta0_vv', 'beta0_vh'],
#       dtype='object')

# %% [markdown]
# Kolom Mg diubah menjadi tipe numerik (karena sebelumnya berupa teks) menggunakan to_numeric.
# Nilai yang tidak bisa dikonversi menjadi NaN dan kemudian dihapus dengan dropna() agar data bersih dari nilai hilang.

# %%
# ubah mg ke folat
df['Mg'] = pd.to_numeric(df['Mg'], errors='coerce')
#hilangkan missing value
df = df.dropna()

# %% [markdown]
# Feature Selection

# %% [markdown]
# * Variabel target (y) adalah kadar Nitrogen (N) dalam tanah.
#
# * Variabel input (X) terdiri dari 30 fitur satelit dan unsur tanah lainnya, seperti spektrum reflektansi (b1–b12) dan sinyal radar (Sigma, gamma, beta).
#
# * Tujuannya: membangun model yang dapat memperkirakan kadar N dari data satelit.

# %%
# x = df[['b2', 'b3', 'b4', 'b8', 'b11', 'Sigma_VV','Sigma_VH']]
# y = df['N']

# %%
X = df[['P', 'K', 'Ca', 'Mg', 'Fe', 'Mn', 'Cu', 'Zn', 'B',
        'b12', 'b11', 'b9', 'b8a', 'b8', 'b7', 'b6', 'b5',
        'b4', 'b3', 'b2', 'b1',
        'Sigma_VV', 'Sigma_VH', 'plia', 'lia', 'iafe',
       'gamma0_vv', 'gamma0_vh', 'beta0_vv', 'beta0_vh']]
y = df['N']

# %% [markdown]
# Splitting Data

# %% [markdown]
# Dataset dibagi menjadi 80% data training dan 20% data testing secara acak, dengan random_state=42 agar hasilnya tetap sama setiap dijalankan.

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Model Linear Regression dibuat dan dilatih menggunakan data training untuk mencari hubungan linear antara fitur satelit dan kadar nitrogen (N).
# Proses fit() menghitung koefisien regresi yang mewakili pengaruh tiap variabel terhadap nilai N.

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# machine

# %%
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("R2 Score :", r2)
print("RMSE:", rmse)
# Out:
# R2 Score : 0.20193023352881245
# RMSE: 0.3499937938811036

# %% [markdown]
# * R² (R-squared) = 0.2019 → artinya model hanya mampu menjelaskan sekitar 20,19% variasi kadar nitrogen (N) berdasarkan fitur-fitur yang digunakan.
#
# * RMSE (Root Mean Squared Error) = 0.35 → menunjukkan tingkat kesalahan prediksi rata-rata sebesar 0.35 satuan (dalam skala N).

# %%
coeff = pd.DataFrame(model.coef_, x.columns, columns=['Coefficient'])
coeff
# Out:
#           Coefficient
# b2          -1.128579
# b3          -2.789536
# b4           4.745031
# b8           0.037338
# b11         -1.192736
# Sigma_VV    -0.020622
# Sigma_VH    -3.695372

# %% [markdown]
# Nilai reflektansi dari band b4 (merah) dan b8 (NIR) berpengaruh positif terhadap kadar nitrogen, sesuai teori vegetasi di penginderaan jauh area dengan klorofil tinggi (lebih hijau) memiliki reflektansi tinggi pada NIR.

# %%
import statsmodels.api as sm

X_sm = sm.add_constant(X_train)
model = sm.OLS(y_train, X_sm).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      N   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     32.52
# Date:                Sat, 08 Nov 2025   Prob (F-statistic):           9.34e-37
# Time:                        06:02:05   Log-Likelihood:                -139.19
# No. Observations:                 473   AIC:                             294.4
# Df Residuals:                     465   BIC:                             327.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5073      0.108     23.173      0.000       2.295       2.720
# ...

# %% [markdown]
# * R-squared = 0.329
#
# * Adj. R² = 0.319
#
# * Beberapa variabel signifikan secara statistik (p < 0.05): b4, b8, b11, dan Sigma_VH
#
# Ini berarti fitur-fitur tersebut secara signifikan mempengaruhi kadar nitrogen (N) dalam model.
# Namun, nilai R² masih relatif rendah, menunjukkan model linear belum cukup untuk memodelkan hubungan kompleks antara data satelit dan kandungan tanah.
